# %% [markdown]
# ## Q1. (4 points)
#  Bubble sort is a simple sorting algorithm that works by repeatedly stepping through a list to be sorted, comparing each pair of adjacent items and swapping them if they are in the wrong order. This process is repeated until after a full pass through the list where no items are swapped. Below is an example of how bubble sort works.
#
# First Pass
#
# `( 5 1 4 2 8 ) → ( 1 5 4 2 8 )`, compare the first two elements, and swap since 5 > 1
#
# `( 1 5 4 2 8 ) → ( 1 4 5 2 8 )`, swap since 5 > 4
#
# `( 1 4 5 2 8 ) → ( 1 4 2 5 8 )`, swap since 5 > 2
#
# `( 1 4 2 5 8 ) → ( 1 4 2 5 8 )`, do not swap since 5 < 8
#
#
#
# Second Pass
#
# `( 1 4 2 5 8 ) → ( 1 4 2 5 8 )`
#
# `( 1 4 2 5 8 ) → ( 1 2 4 5 8 )`, swap since 4 > 2
#
# `( 1 2 4 5 8 ) → ( 1 2 4 5 8 )`
#
# `( 1 2 4 5 8 ) → ( 1 2 4 5 8 )`, we swapped on this iteration, so one more iteration is needed
#
#
#
# Third Pass
#
# `( 1 2 4 5 8 ) → ( 1 2 4 5 8 )`
#
# `( 1 2 4 5 8 ) → ( 1 2 4 5 8 )`
#
# `( 1 2 4 5 8 ) → ( 1 2 4 5 8 )`
#
# `( 1 2 4 5 8 ) → ( 1 2 4 5 8 )`, no swaps on this iteration, so we are done
#
#
#
#
# ##### (a) Write a Python function, `bubble_sort`, that performs bubble sort. Verify that your function works by testing it on the following four lists, printing the lists before and after the sort:
#
# - `list1 = [5,1,4,2,8]`
# - `list2 = ["aa","a","a1","bat","baa","ba","b"]`
# - `list3 = ["5","1","11","3","03"]`
# - a list of twenty randomly generated integers between 0 and 100.

# %%
## RUN TIME COMPLEXITY OF BUBBLE SORT ##
# It's O(n^2)
# Each loop of the program has a run time that is a function of the length of the list. Since our list can be infinite, and we have a loop with a nested loop, it's n * n = n^2.
# while True worst case is n, and the for loops worst case is n. 

# import random for the list 4
import random 

## need to define bubble_sort
def bubble_sort(sortList): 
    
    # using an infinite because we'll break the loop later
    while True:
        # make the flag to indicate we haven't done swaps
        no_swaps = True
        # loop over the list
        for i in range(0, len(sortList) - 1):
            # check to see if they need to be swap
            if sortList[i] > sortList[i + 1]:
                # swap them 
                sortList[i], sortList[i + 1] = sortList[i + 1], sortList[i]
                # set our flag for this iteration, because we've already done at least one swap
                no_swaps = False
        # break as soon as we go through an iteration that hasn't swapped
        if no_swaps:
            break
        # print it for each step 
        print(sortList)

list1 = [5,1,4,2,8]
list2 = ["aa","a","a1","bat","baa","ba","b"]
list3 = ["5","1","11","3","03"]

list4 = []
for i in range(20):
    list4.append(random.randrange(0, 101))


# added the prints at the end of each to verify the sorting outcome because I don't know how 
# alphanumerics or ints as strings are ordered :) 
# feel free to uncomment if you want to verify any 

bubble_sort(list1)
#print(sorted(list1))
bubble_sort(list2)
#print(sorted(list2))
bubble_sort(list3)
#print(sorted(list3))
bubble_sort(list4)
#print(sorted(list4))
# Out:
# [1, 4, 2, 5, 8]
# [1, 2, 4, 5, 8]
# ['a', 'a1', 'aa', 'baa', 'ba', 'b', 'bat']
# ['a', 'a1', 'aa', 'ba', 'b', 'baa', 'bat']
# ['a', 'a1', 'aa', 'b', 'ba', 'baa', 'bat']
# ['1', '11', '3', '03', '5']
# ['1', '11', '03', '3', '5']
# ['1', '03', '11', '3', '5']
# ['03', '1', '11', '3', '5']
# [7, 45, 76, 21, 88, 55, 9, 36, 71, 58, 79, 68, 9, 66, 33, 18, 46, 67, 10, 94]
# [7, 45, 21, 76, 55, 9, 36, 71, 58, 79, 68, 9, 66, 33, 18, 46, 67, 10, 88, 94]
# [7, 21, 45, 55, 9, 36, 71, 58, 76, 68, 9, 66, 33, 18, 46, 67, 10, 79, 88, 94]
# [7, 21, 45, 9, 36, 55, 58, 71, 68, 9, 66, 33, 18, 46, 67, 10, 76, 79, 88, 94]
# [7, 21, 9, 36, 45, 55, 58, 68, 9, 66, 33, 18, 46, 67, 10, 71, 76, 79, 88, 94]
# [7, 9, 21, 36, 45, 55, 58, 9, 66, 33, 18, 46, 67, 10, 68, 71, 76, 79, 88, 94]
# [7, 9, 21, 36, 45, 55, 9, 58, 33, 18, 46, 66, 10, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 21, 36, 45, 9, 55, 33, 18, 46, 58, 10, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 21, 36, 9, 45, 33, 18, 46, 55, 10, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 21, 9, 36, 33, 18, 45, 46, 10, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 9, 21, 33, 18, 36, 45, 10, 46, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 9, 21, 18, 33, 36, 10, 45, 46, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 9, 18, 21, 33, 10, 36, 45, 46, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 9, 18, 21, 10, 33, 36, 45, 46, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 9, 18, 10, 21, 33, 36, 45, 46, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]
# [7, 9, 9, 10, 18, 21, 33, 36, 45, 46, 55, 58, 66, 67, 68, 71, 76, 79, 88, 94]

# %% [markdown]
# ## Q2. (8 points)
#
# Implement a recursive binary search function, `binary_search`, which allows you to search a sorted list of items for a specific target.
#
# Your recursive function should take four input parameters: `list` (a sorted list), `key` (the item being searched for), a `left_index` into the list, and a `right_index` into the list. Your function looks only in the sublist starting at the `left_index`, and ending at the `right_index` (including the item at the `right_index` position).
#
# For example, suppose that the_list is:
#
# `[27, 78, 105, 135, 411, 431, 434, 468, 493, 501, 525, 534, 551, 654, 780]`
#
# which contains 15 items, indexed 0 to 14.
#
#
#
#  If I call `binary_search(the_list, 135, 0, 14)`, then I'm considering the entire list, and the return value should be 3, since the key `135` appears at index 3.
#
#   If I call `binary_search(the_list, 500, 0, 14)`, the return value should be `None`, since the key `500` is not in `the_list`. The call `binary_search(the_list, 135, 2, 12)` should return 3 since, as before, the key `135` appears at index 3 in `the_list`.
#
#   Notice that the index returned is the index in the entire list, not the relative index in the sublist starting at `left_index`. The parameters `left_index` and `right_index` just give the range of indices into the list that we are considering in a given call of `binary_search`.
#
#
# ##### Here is what you need to do in your `binary_search` function:
#
# - If the sublist of `the_list` starting at `left_index` and ending at `right_index` is empty, then the key cannot be in the sublist -- return `None`.
# - Otherwise, the sublist is not empty, and you should:
#     - Compute the midpoint of this sublist, by taking the average of `left_index` and `right_index`, and rounding to the nearest integer as needed.
#     - If `key` is equal in value to the item at midpoint, then it has been found. Return this index.
#     - Otherwise, because `the_list` is sorted, you can tell whether `key`, if in `the_list`, is either in the sublist before `midpoint` or in the sublist after `midpoint`.
#     - If key is less than the item at midpoint and it's in the list, then it must be in the sublist before  `midpoint`. Recursively return the result of calling `binary_search` on the sublist starting at `left_index` and going up to and including the index just before `midpoint`.
#     - Only one other possibility remains: `key` is greater than the item at `midpoint`, and so if it's in the list, then it must be in the sublist after `midpoint`. Recursively return the result of calling `binary_search` on the sublist starting at the index just after `midpoint` and going up to and including `right_index`.
#
# ##### Once you have written your recursive binary search function, you should write a simple user interface as follows:
#
# - Prompt the user to specify the number of elements `(N)` in a list that you will create to be searched.
# - Generate a list of `N` random integers, with each integer in the range of 0 to 1000, then sort it. (You can use your very own `bubble_sort` function from Q1 above, or Python's built-in function sort() or sorted, to sort this list).
# - Print the list so that the user can see it.
# - Prompt the user for input from the keyboard. If the user enters "?", print the list. If the user enters "q", quit the search interface. Otherwise search the list for the element that the user entered.
# - Repeat step 4 until the user quits.

# %%
# define the function
def binary_search(the_list, key, left_index, right_index):
    # doing >= because the left_index shouldn't be greater than right index anyway, also catches = 
    if left_index >= right_index:
        return None
   
    # make the sublist
    the_sublist = the_list[left_index: right_index]
    print(the_sublist)
    # calculate the midpoint, round down
    midpoint = len(the_sublist) // 2
    print("The midpoint is:", midpoint)
    # printing for checking the math, looks good 
    #print(midpoint)

    if the_list[midpoint] == key:
        return midpoint
    elif the_list[midpoint] > key:
        return binary_search(the_list, key, left_index, midpoint)
    elif the_list[midpoint] < key:
        return binary_search(the_list, key, midpoint, right_index)
    else:
        return None


    



## MAIN 
the_list = [27, 78, 105, 135, 411, 431, 434, 468, 493, 501, 525, 534, 551, 654, 780]
print(binary_search(the_list, 135, 0, 14)) # fine
print(binary_search(the_list, 500, 0, 14))
print(binary_search(the_list, 135, 2, 12))
# Out:
# [27, 78, 105, 135, 411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 7
# [27, 78, 105, 135, 411, 431, 434]
# The midpoint is: 3
# 3
# [27, 78, 105, 135, 411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 7
# [468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 3
# [135, 411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# ...
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# [431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 4
# [411, 431, 434, 468, 493, 501, 525, 534, 551, 654]
# The midpoint is: 5
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/threading.py:1073, in Thread._wait_for_tstate_lock(self, block, timeout)
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1071'>1072</a> try:
# -> <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1072'>1073</a>     if lock.acquire(block, timeout):
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1073'>1074</a>         lock.release()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# /Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment 2/a2_dwhite.ipynb Cell 5' in <cell line: 33>()
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=30'>31</a> the_list = [27, 78, 105, 135, 411, 431, 434, 468, 493, 501, 525, 534, 551, 654, 780]
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=31'>32</a> print(binary_search(the_list, 135, 0, 14)) # fine
# ---> <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=32'>33</a> print(binary_search(the_list, 500, 0, 14))
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=33'>34</a> print(binary_search(the_list, 135, 2, 12))
#
# /Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment 2/a2_dwhite.ipynb Cell 5' in binary_search(the_list, key, left_index, right_index)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=18'>19</a>     return binary_search(the_list, key, left_index, midpoint)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=19'>20</a> elif the_list[midpoint] < key:
# ---> <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=20'>21</a>     return binary_search(the_list, key, midpoint, right_index)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=21'>22</a> else:
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=22'>23</a>     return None
#
# /Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment 2/a2_dwhite.ipynb Cell 5' in binary_search(the_list, key, left_index, right_index)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=18'>19</a>     return binary_search(the_list, key, left_index, midpoint)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=19'>20</a> elif the_list[midpoint] < key:
# ---> <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=20'>21</a>     return binary_search(the_list, key, midpoint, right_index)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=21'>22</a> else:
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=22'>23</a>     return None
#
#     [... skipping similar frames: binary_search at line 21 (2964 times)]
#
# /Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment 2/a2_dwhite.ipynb Cell 5' in binary_search(the_list, key, left_index, right_index)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=18'>19</a>     return binary_search(the_list, key, left_index, midpoint)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=19'>20</a> elif the_list[midpoint] < key:
# ---> <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=20'>21</a>     return binary_search(the_list, key, midpoint, right_index)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=21'>22</a> else:
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=22'>23</a>     return None
#
# /Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment 2/a2_dwhite.ipynb Cell 5' in binary_search(the_list, key, left_index, right_index)
#       <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=6'>7</a> # make the sublist
#       <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=7'>8</a> the_sublist = the_list[left_index: right_index]
# ----> <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=8'>9</a> print(the_sublist)
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=9'>10</a> # calculate the midpoint, round down
#      <a href='vscode-notebook-cell:/Users/drakewhite/Documents/GitHub/INFO-206B/Assignments/Assignment%202/a2_dwhite.ipynb#ch0000005?line=10'>11</a> midpoint = len(the_sublist) // 2
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py:531, in OutStream.write(self, string)
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=528'>529</a> is_child = (not self._is_master_process())
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=529'>530</a> # only touch the buffer in the IO thread to avoid races
# --> <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=530'>531</a> self.pub_thread.schedule(lambda: self._buffer.write(string))
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=531'>532</a> if is_child:
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=532'>533</a>     # mp.Pool cannot be trusted to flush promptly (or ever),
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=533'>534</a>     # and this helps.
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=534'>535</a>     if self._subprocess_flush_pending:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py:213, in IOPubThread.schedule(self, f)
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=207'>208</a> def schedule(self, f):
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=208'>209</a>     """Schedule a function to be called in our IO thread.
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=209'>210</a>
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=210'>211</a>     If the thread is not running, call immediately.
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=211'>212</a>     """
# --> <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=212'>213</a>     if self.thread.is_alive():
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=213'>214</a>         self._events.append(f)
#     <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py?line=214'>215</a>         # wake event thread (message content is ignored)
#
# File ~/opt/anaconda3/lib/python3.9/threading.py:1137, in Thread.is_alive(self)
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1134'>1135</a> if self._is_stopped or not self._started.is_set():
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1135'>1136</a>     return False
# -> <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1136'>1137</a> self._wait_for_tstate_lock(False)
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1137'>1138</a> return not self._is_stopped
#
# File ~/opt/anaconda3/lib/python3.9/threading.py:1077, in Thread._wait_for_tstate_lock(self, block, timeout)
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1074'>1075</a>         self._stop()
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1075'>1076</a> except:
# -> <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1076'>1077</a>     if lock.locked():
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1077'>1078</a>         # bpo-45274: lock.acquire() acquired the lock, but the function
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1078'>1079</a>         # was interrupted with an exception before reaching the
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1079'>1080</a>         # lock.release(). It can happen if a signal handler raises an
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1080'>1081</a>         # exception, like CTRL+C which raises KeyboardInterrupt.
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1081'>1082</a>         lock.release()
#    <a href='file:///Users/drakewhite/opt/anaconda3/lib/python3.9/threading.py?line=1082'>1083</a>         self._stop()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
